# %% [markdown]
# # **Exploratory Data Analysis in Python using pandas**
#
# In this Jupyter notebook, I will be showing you how to perform Exploratory Data Analysis on web scraped data of NBA player stats

# %% [markdown]
# ## **Web scraping data using pandas**
#
# The following block of code will retrieve the "2021-22 NBA Player Stats: Per Game" data from http://www.basketball-reference.com/.

# %%
import pandas as pd

# Retrieve HTML table data
url = 'https://www.basketball-reference.com/leagues/NBA_2022_per_game.html'
html = pd.read_html(url, header = 0)
df2022 = html[0]

# %%
df2022
# Out:
#       Rk             Player Pos Age   Tm   G  GS    MP   FG   FGA  ...   FT%  \
# 0      1   Precious Achiuwa   C  22  TOR  73  28  23.6  3.6   8.3  ...  .595
# 1      2       Steven Adams   C  28  MEM  76  75  26.3  2.8   5.1  ...  .543
# 2      3        Bam Adebayo   C  24  MIA  56  56  32.6  7.3  13.0  ...  .753
# 3      4       Santi Aldama  PF  21  MEM  32   0  11.3  1.7   4.1  ...  .625
# 4      5  LaMarcus Aldridge   C  36  BRK  47  12  22.3  5.4   9.7  ...  .873
# ..   ...                ...  ..  ..  ...  ..  ..   ...  ...   ...  ...   ...
# 837  601     Thaddeus Young  PF  33  TOR  26   0  18.3  2.6   5.5  ...  .481
# 838  602         Trae Young  PG  23  ATL  76  76  34.9  9.4  20.3  ...  .904
# 839  603     Omer Yurtseven   C  23  MIA  56  12  12.6  2.3   4.4  ...  .623
# 840  604        Cody Zeller   C  29  POR  27   0  13.1  1.9   3.3  ...  .776
# 841  605        Ivica Zubac   C  24  LAC  76  76  24.4  4.1   6.5  ...  .727
#
#      ORB  DRB   TRB  AST  STL  BLK  TOV   PF   PTS
# 0    2.0  4.5   6.5  1.1  0.5  0.6  1.2  2.1   9.1
# 1    4.6  5.4  10.0  3.4  0.9  0.8  1.5  2.0   6.9
# 2    2.4  7.6  10.1  3.4  1.4  0.8  2.6  3.1  19.1
# 3    1.0  1.7   2.7  0.7  0.2  0.3  0.5  1.1   4.1
# 4    1.6  3.9   5.5  0.9  0.3  1.0  0.9  1.7  12.9
# ..   ...  ...   ...  ...  ...  ...  ...  ...   ...
# 837  1.5  2.9   4.4  1.7  1.2  0.4  0.8  1.7   6.3
# 838  0.7  3.1   3.7  9.7  0.9  0.1  4.0  1.7  28.4
# 839  1.5  3.7   5.3  0.9  0.3  0.4  0.7  1.5   5.3
# 840  1.9  2.8   4.6  0.8  0.3  0.2  0.7  2.1   5.2
# 841  2.9  5.6   8.5  1.6  0.5  1.0  1.5  2.7  10.3
#
# [842 rows x 30 columns]

# %% [markdown]
# Check the "Age" column. Do we need to do anything?

# %%
df2022.Age.value_counts()
# Out:
# Age
# 24     104
# 23      81
# 22      73
# 26      68
# 25      65
# 28      60
# 27      53
# 29      50
# 21      48
# 31      42
# 30      33
# 20      31
# Age     30
# 32      29
# 33      23
# 35      14
# 19      13
# 34      11
# 36       9
# 37       2
# 41       1
# 38       1
# 40       1
# Name: count, dtype: int64

# %%
# Data cleaning if needed
df = df2022[df2022.Age != 'Age']
df.Age.value_counts()
df.reset_index(drop=True)
# Out:
#       Rk             Player Pos Age   Tm   G  GS    MP   FG   FGA  ...   FT%  \
# 0      1   Precious Achiuwa   C  22  TOR  73  28  23.6  3.6   8.3  ...  .595
# 1      2       Steven Adams   C  28  MEM  76  75  26.3  2.8   5.1  ...  .543
# 2      3        Bam Adebayo   C  24  MIA  56  56  32.6  7.3  13.0  ...  .753
# 3      4       Santi Aldama  PF  21  MEM  32   0  11.3  1.7   4.1  ...  .625
# 4      5  LaMarcus Aldridge   C  36  BRK  47  12  22.3  5.4   9.7  ...  .873
# ..   ...                ...  ..  ..  ...  ..  ..   ...  ...   ...  ...   ...
# 807  601     Thaddeus Young  PF  33  TOR  26   0  18.3  2.6   5.5  ...  .481
# 808  602         Trae Young  PG  23  ATL  76  76  34.9  9.4  20.3  ...  .904
# 809  603     Omer Yurtseven   C  23  MIA  56  12  12.6  2.3   4.4  ...  .623
# 810  604        Cody Zeller   C  29  POR  27   0  13.1  1.9   3.3  ...  .776
# 811  605        Ivica Zubac   C  24  LAC  76  76  24.4  4.1   6.5  ...  .727
#
#      ORB  DRB   TRB  AST  STL  BLK  TOV   PF   PTS
# 0    2.0  4.5   6.5  1.1  0.5  0.6  1.2  2.1   9.1
# 1    4.6  5.4  10.0  3.4  0.9  0.8  1.5  2.0   6.9
# 2    2.4  7.6  10.1  3.4  1.4  0.8  2.6  3.1  19.1
# 3    1.0  1.7   2.7  0.7  0.2  0.3  0.5  1.1   4.1
# 4    1.6  3.9   5.5  0.9  0.3  1.0  0.9  1.7  12.9
# ..   ...  ...   ...  ...  ...  ...  ...  ...   ...
# 807  1.5  2.9   4.4  1.7  1.2  0.4  0.8  1.7   6.3
# 808  0.7  3.1   3.7  9.7  0.9  0.1  4.0  1.7  28.4
# 809  1.5  3.7   5.3  0.9  0.3  0.4  0.7  1.5   5.3
# 810  1.9  2.8   4.6  0.8  0.3  0.2  0.7  2.1   5.2
# 811  2.9  5.6   8.5  1.6  0.5  1.0  1.5  2.7  10.3
#
# [812 rows x 30 columns]

# %% [markdown]
# ## **Acronyms**
#
#
# Acronym | Description
# ---|---
# Rk | Rank
# Pos | Position
# Age | Player's age on February 1 of the season
# Tm | Team
# G | Games
# GS | Games Started
# MP | Minutes Played Per Game
# FG | Field Goals Per Game
# FGA | Field Goal Attempts Per Game
# FG% | Field Goal Percentage
# 3P | 3-Point Field Goals Per Game
# 3PA | 3-Point Field Goal Attempts Per Game
# 3P% | FG% on 3-Pt FGAs.
# 2P | 2-Point Field Goals Per Game
# 2PA | 2-Point Field Goal Attempts Per Game
# 2P% | FG% on 2-Pt FGAs.
# eFG% | Effective Field Goal Percentage
# | *(Note: This statistic adjusts for the fact that a 3-point field goal is worth one more point than a 2-point field goal.)*
# FT | Free Throws Per Game
# FTA | Free Throw Attempts Per Game
# FT% | Free Throw Percentage
# ORB | Offensive Rebounds Per Game
# DRB | Defensive Rebounds Per Game
# TRB | Total Rebounds Per Game
# AST | Assists Per Game
# STL | Steals Per Game
# BLK | Blocks Per Game
# TOV | Turnovers Per Game
# PF | Personal Fouls Per Game
# PTS | Points Per Game

# %% [markdown]
# ## **Data cleaning**

# %% [markdown]
# ### Data dimension

# %%
df.shape
# Out:
# (812, 30)

# %% [markdown]
# ### Dataframe contents

# %%
df.head(10)
# Out:
#   Rk                    Player Pos Age   Tm   G  GS    MP   FG   FGA  ...  \
# 0  1          Precious Achiuwa   C  22  TOR  73  28  23.6  3.6   8.3  ...
# 1  2              Steven Adams   C  28  MEM  76  75  26.3  2.8   5.1  ...
# 2  3               Bam Adebayo   C  24  MIA  56  56  32.6  7.3  13.0  ...
# 3  4              Santi Aldama  PF  21  MEM  32   0  11.3  1.7   4.1  ...
# 4  5         LaMarcus Aldridge   C  36  BRK  47  12  22.3  5.4   9.7  ...
# 5  6  Nickeil Alexander-Walker  SG  23  TOT  65  21  22.6  3.9  10.5  ...
# 6  6  Nickeil Alexander-Walker  SG  23  NOP  50  19  26.3  4.7  12.6  ...
# 7  6  Nickeil Alexander-Walker  SG  23  UTA  15   2   9.9  1.1   3.2  ...
# 8  7             Grayson Allen  SG  26  MIL  66  61  27.3  3.9   8.6  ...
# 9  8             Jarrett Allen   C  23  CLE  56  56  32.3  6.6   9.7  ...
#
#     FT%  ORB  DRB   TRB  AST  STL  BLK  TOV   PF   PTS
# 0  .595  2.0  4.5   6.5  1.1  0.5  0.6  1.2  2.1   9.1
# 1  .543  4.6  5.4  10.0  3.4  0.9  0.8  1.5  2.0   6.9
# 2  .753  2.4  7.6  10.1  3.4  1.4  0.8  2.6  3.1  19.1
# 3  .625  1.0  1.7   2.7  0.7  0.2  0.3  0.5  1.1   4.1
# 4  .873  1.6  3.9   5.5  0.9  0.3  1.0  0.9  1.7  12.9
# 5  .743  0.6  2.3   2.9  2.4  0.7  0.4  1.4  1.6  10.6
# 6  .722  0.7  2.6   3.3  2.8  0.8  0.4  1.7  1.8  12.8
# 7  .917  0.1  1.5   1.5  1.1  0.3  0.3  0.5  1.0   3.5
# 8  .865  0.5  2.9   3.4  1.5  0.7  0.3  0.7  1.5  11.1
# 9  .708  3.4  7.3  10.8  1.6  0.8  1.3  1.7  1.7  16.1
#
# [10 rows x 30 columns]

# %% [markdown]
# ### Check for missing values

# %%
df.isnull().sum()
# Out:
# Rk         0
# Player     0
# Pos        0
# Age        0
# Tm         0
# G          0
# GS         0
# MP         0
# FG         0
# FGA        0
# FG%       15
# 3P         0
# 3PA        0
# 3P%       72
# 2P         0
# 2PA        0
# 2P%       28
# eFG%      15
# FT         0
# FTA        0
# FT%       97
# ORB        0
# DRB        0
# TRB        0
# AST        0
# STL        0
# BLK        0
# TOV        0
# PF         0
# PTS        0
# dtype: int64

# %% [markdown]
# ### Replace missing values with 0

# %%
df = df.fillna(0)
df.isnull().sum()
# Out:
# Rk        0
# Player    0
# Pos       0
# Age       0
# Tm        0
# G         0
# GS        0
# MP        0
# FG        0
# FGA       0
# FG%       0
# 3P        0
# 3PA       0
# 3P%       0
# 2P        0
# 2PA       0
# 2P%       0
# eFG%      0
# FT        0
# FTA       0
# FT%       0
# ORB       0
# DRB       0
# TRB       0
# AST       0
# STL       0
# BLK       0
# TOV       0
# PF        0
# PTS       0
# dtype: int64

# %% [markdown]
# ## **Exploratory Data Analysis**

# %% [markdown]
# #### Displays the dataframe

# %%
df
# Out:
#       Rk             Player Pos Age   Tm   G  GS    MP   FG   FGA  ...   FT%  \
# 0      1   Precious Achiuwa   C  22  TOR  73  28  23.6  3.6   8.3  ...  .595
# 1      2       Steven Adams   C  28  MEM  76  75  26.3  2.8   5.1  ...  .543
# 2      3        Bam Adebayo   C  24  MIA  56  56  32.6  7.3  13.0  ...  .753
# 3      4       Santi Aldama  PF  21  MEM  32   0  11.3  1.7   4.1  ...  .625
# 4      5  LaMarcus Aldridge   C  36  BRK  47  12  22.3  5.4   9.7  ...  .873
# ..   ...                ...  ..  ..  ...  ..  ..   ...  ...   ...  ...   ...
# 837  601     Thaddeus Young  PF  33  TOR  26   0  18.3  2.6   5.5  ...  .481
# 838  602         Trae Young  PG  23  ATL  76  76  34.9  9.4  20.3  ...  .904
# 839  603     Omer Yurtseven   C  23  MIA  56  12  12.6  2.3   4.4  ...  .623
# 840  604        Cody Zeller   C  29  POR  27   0  13.1  1.9   3.3  ...  .776
# 841  605        Ivica Zubac   C  24  LAC  76  76  24.4  4.1   6.5  ...  .727
#
#      ORB  DRB   TRB  AST  STL  BLK  TOV   PF   PTS
# 0    2.0  4.5   6.5  1.1  0.5  0.6  1.2  2.1   9.1
# 1    4.6  5.4  10.0  3.4  0.9  0.8  1.5  2.0   6.9
# 2    2.4  7.6  10.1  3.4  1.4  0.8  2.6  3.1  19.1
# 3    1.0  1.7   2.7  0.7  0.2  0.3  0.5  1.1   4.1
# 4    1.6  3.9   5.5  0.9  0.3  1.0  0.9  1.7  12.9
# ..   ...  ...   ...  ...  ...  ...  ...  ...   ...
# 837  1.5  2.9   4.4  1.7  1.2  0.4  0.8  1.7   6.3
# 838  0.7  3.1   3.7  9.7  0.9  0.1  4.0  1.7  28.4
# 839  1.5  3.7   5.3  0.9  0.3  0.4  0.7  1.5   5.3
# 840  1.9  2.8   4.6  0.8  0.3  0.2  0.7  2.1   5.2
# 841  2.9  5.6   8.5  1.6  0.5  1.0  1.5  2.7  10.3
#
# [812 rows x 30 columns]

# %% [markdown]
# ### Overview of data types of each columns in the dataframe

# %%
df.dtypes
# Out:
# Rk        object
# Player    object
# Pos       object
# Age       object
# Tm        object
# G         object
# GS        object
# MP        object
# FG        object
# FGA       object
# FG%       object
# 3P        object
# 3PA       object
# 3P%       object
# 2P        object
# 2PA       object
# 2P%       object
# eFG%      object
# FT        object
# FTA       object
# FT%       object
# ORB       object
# DRB       object
# TRB       object
# AST       object
# STL       object
# BLK       object
# TOV       object
# PF        object
# PTS       object
# dtype: object

# %%
# export dataframe
df.to_csv("basektball.csv", index=False, header=True)

# %%
df = pd.read_csv("basektball.csv")
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 812 entries, 0 to 811
# Data columns (total 30 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Rk      812 non-null    int64
#  1   Player  812 non-null    object
#  2   Pos     812 non-null    object
#  3   Age     812 non-null    int64
#  4   Tm      812 non-null    object
#  5   G       812 non-null    int64
#  6   GS      812 non-null    int64
#  7   MP      812 non-null    float64
#  8   FG      812 non-null    float64
#  9   FGA     812 non-null    float64
#  10  FG%     797 non-null    float64
#  11  3P      812 non-null    float64
#  12  3PA     812 non-null    float64
#  13  3P%     740 non-null    float64
#  14  2P      812 non-null    float64
#  15  2PA     812 non-null    float64
#  16  2P%     784 non-null    float64
#  17  eFG%    797 non-null    float64
#  18  FT      812 non-null    float64
#  19  FTA     812 non-null    float64
#  20  FT%     715 non-null    float64
#  21  ORB     812 non-null    float64
#  22  DRB     812 non-null    float64
#  23  TRB     812 non-null    float64
#  24  AST     812 non-null    float64
#  25  STL     812 non-null    float64
#  26  BLK     812 non-null    float64
#  27  TOV     812 non-null    float64
#  28  PF      812 non-null    float64
#  29  PTS     812 non-null    float64
# dtypes: float64(23), int64(4), object(3)
# memory usage: 190.4+ KB

# %% [markdown]
# ## **QUESTIONS**

# %% [markdown]
# ### **Conditional Selection**
#
# In performing exploratory data analysis, it is important to be able to select subsets of data to perform analysis or comparisons.

# %% [markdown]
# **Which player scored the most Points (PTS) Per Game?**
# Here, we will return the entire row.

# %%
df.Player.value_counts()
# Out:
# Player
# Greg Monroe         5
# Isaiah Thomas       4
# Tristan Thompson    4
# Wenyen Gabriel      4
# James Ennis III     4
#                    ..
# Javonte Green       1
# JaMychal Green      1
# Jalen Green         1
# Draymond Green      1
# Ivica Zubac         1
# Name: count, Length: 605, dtype: int64

# %%
df[df.PTS == df.PTS.max()]
# Out:
#       Rk       Player Pos  Age   Tm   G  GS    MP   FG   FGA  ...    FT%  ORB  \
# 206  162  Joel Embiid   C   27  PHI  68  68  33.8  9.8  19.6  ...  0.814  2.1
#
#      DRB   TRB  AST  STL  BLK  TOV   PF   PTS
# 206  9.6  11.7  4.2  1.1  1.5  3.1  2.7  30.6
#
# [1 rows x 30 columns]

# %%
# player scores the most points in total
total_pts = df.groupby("Player").sum()
total_pts[total_pts.PTS == total_pts.PTS.max()]
# Out:
#                Rk     Pos  Age         Tm    G   GS     MP    FG   FGA    FG%  \
# Player
# CJ McCollum  1086  SGSGSG   90  TOTPORNOP  124  124  103.6  26.2  56.5  1.389
#
#              ...    FT%  ORB   DRB   TRB   AST  STL  BLK  TOV   PF   PTS
# Player       ...
# CJ McCollum  ...  2.055  2.5  10.5  13.1  15.4  3.4  1.0  6.1  5.8  66.9
#
# [1 rows x 29 columns]

# %% [markdown]
# We will return specific column values.
#
# Further question, what team is the player from?

# %% [markdown]
# Which position is the player playing as?

# %% [markdown]
# How many games did the player played in the season?

# %% [markdown]
# **Which player scored more than 20 Points (PTS) Per Game?**

# %%
df[df.PTS > 20]
# Out:
#       Rk                   Player Pos  Age   Tm   G  GS    MP    FG   FGA  \
# 15    12    Giannis Antetokounmpo  PF   27  MIL  67  67  32.9  10.3  18.6
# 32    25              LaMelo Ball  PG   20  CHO  75  75  32.3   7.2  16.7
# 48    41             Bradley Beal  SG   28  WAS  40  40  36.0   8.7  19.3
# 70    59             Devin Booker  SG   25  PHO  68  68  34.5   9.7  20.9
# 78    67            Miles Bridges  PF   23  CHO  80  80  35.5   7.5  15.2
# 93    76             Jaylen Brown  SF   25  BOS  66  66  33.6   8.7  18.4
# 106   87             Jimmy Butler  SF   32  MIA  57  57  33.9   7.0  14.5
# 159  126            Stephen Curry  PG   33  GSW  64  64  34.5   8.4  19.1
# 160  127            Anthony Davis   C   28  LAL  40  40  35.1   9.3  17.4
# 167  134            DeMar DeRozan  PF   32  CHI  76  76  36.1  10.2  20.2
# 178  141              Luka Dončić  PG   22  DAL  65  65  35.4   9.9  21.6
# 198  154             Kevin Durant  PF   33  BRK  55  55  37.2  10.5  20.3
# 200  156          Anthony Edwards  SG   20  MIN  72  72  34.3   7.6  17.3
# 206  162              Joel Embiid   C   27  PHI  68  68  33.8   9.8  19.6
# 230  175             De'Aaron Fox  PG   24  SAC  59  59  35.3   8.7  18.5
# 736  ...  0.822  2.6   7.2   9.8   3.6  1.0  1.1  3.1  3.6  24.6
# 748  ...  0.874  0.7   3.8   4.4   6.7  1.7  0.5  2.6  2.5  20.3
# 808  ...  0.904  0.7   3.1   3.7   9.7  0.9  0.1  4.0  1.7  28.4
#
# [45 rows x 30 columns]

# %% [markdown]
# **Which player had the highest 3-Point Field Goals Per Game (3P) ?**

# %%
df[df['3P'] == df['3P'].max()]
# Out:
#       Rk         Player Pos  Age   Tm   G  GS    MP   FG   FGA  ...    FT%  \
# 159  126  Stephen Curry  PG   33  GSW  64  64  34.5  8.4  19.1  ...  0.923
#
#      ORB  DRB  TRB  AST  STL  BLK  TOV   PF   PTS
# 159  0.5  4.7  5.2  6.3  1.3  0.4  3.2  2.0  25.5
#
# [1 rows x 30 columns]

# %% [markdown]
# **Which player had the highest Assists Per Game (AST) ?**

# %% [markdown]
# ### **GroupBy() function**

# %% [markdown]
# **Which player scored the highest (PTS) in the Los Angeles Lakers?**

# %%
df[df.Tm == "LAL" & (df.PTS == df.PTS.max())]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~/.pyenv/versions/3.11.4/envs/AI/lib/python3.11/site-packages/pandas/core/ops/array_ops.py:311, in na_logical_op(x, y, op)
#     302 try:
#     303     # For exposition, write:
#     304     #  yarr = isinstance(y, np.ndarray)
#    (...)
#     309     # Then Cases where this goes through without raising include:
#     310     #  (xint or xbool) and (yint or bool)
# --> 311     result = op(x, y)
#     312 except TypeError:
#
# File ~/.pyenv/versions/3.11.4/envs/AI/lib/python3.11/site-packages/pandas/core/roperator.py:54, in rand_(left, right)
#      53 def rand_(left, right):
# ---> 54     return operator.and_(right, left)
#
# TypeError: ufunc 'bitwise_and' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# File ~/.pyenv/versions/3.11.4/envs/AI/lib/python3.11/site-packages/pandas/core/ops/array_ops.py:325, in na_logical_op(x, y, op)
#     324 try:
# --> 325     result = libops.scalar_binop(x, y, op)
#     326 except (
#     327     TypeError,
#     328     ValueError,
#    (...)
#     331     NotImplementedError,
#     332 ) as err:
#
# File ~/.pyenv/versions/3.11.4/envs/AI/lib/python3.11/site-packages/pandas/_libs/ops.pyx:180, in pandas._libs.ops.scalar_binop()
#
# ValueError: Buffer dtype mismatch, expected 'Python object' but got 'bool'
#
# The above exception was the direct cause of the following exception:
#
# TypeError                                 Traceback (most recent call last)
# Cell In[52], line 1
# ----> 1 df[df.Tm == "LAL" & (df.PTS == df.PTS.max())]
#
# File ~/.pyenv/versions/3.11.4/envs/AI/lib/python3.11/site-packages/pandas/core/ops/common.py:81, in _unpack_zerodim_and_defer.<locals>.new_method(self, other)
#      77             return NotImplemented
#      79 other = item_from_zerodim(other)
# ---> 81 return method(self, other)
#
# File ~/.pyenv/versions/3.11.4/envs/AI/lib/python3.11/site-packages/pandas/core/arraylike.py:74, in OpsMixin.__rand__(self, other)
#      72 @unpack_zerodim_and_defer("__rand__")
#      73 def __rand__(self, other):
# ---> 74     return self._logical_method(other, roperator.rand_)
#
# File ~/.pyenv/versions/3.11.4/envs/AI/lib/python3.11/site-packages/pandas/core/series.py:6107, in Series._logical_method(self, other, op)
#    6104 lvalues = self._values
#    6105 rvalues = extract_array(other, extract_numpy=True, extract_range=True)
# -> 6107 res_values = ops.logical_op(lvalues, rvalues, op)
#    6108 return self._construct_result(res_values, name=res_name)
#
# File ~/.pyenv/versions/3.11.4/envs/AI/lib/python3.11/site-packages/pandas/core/ops/array_ops.py:401, in logical_op(left, right, op)
#     397 # For int vs int `^`, `|`, `&` are bitwise operators and return
#     398 #   integer dtypes.  Otherwise these are boolean ops
#     399 filler = fill_int if is_self_int_dtype and is_other_int_dtype else fill_bool
# --> 401 res_values = na_logical_op(lvalues, rvalues, op)
#     402 # error: Cannot call function of unknown type
#     403 res_values = filler(res_values)  # type: ignore[operator]
#
# File ~/.pyenv/versions/3.11.4/envs/AI/lib/python3.11/site-packages/pandas/core/ops/array_ops.py:334, in na_logical_op(x, y, op)
#     326         except (
#     327             TypeError,
#     328             ValueError,
#    (...)
#     331             NotImplementedError,
#     332         ) as err:
#     333             typ = type(y).__name__
# --> 334             raise TypeError(
#     335                 f"Cannot perform '{op.__name__}' with a dtyped [{x.dtype}] array "
#     336                 f"and scalar of type [{typ}]"
#     337             ) from err
#     339 return result.reshape(x.shape)
#
# TypeError: Cannot perform 'rand_' with a dtyped [bool] array and scalar of type [bool]

# %% [markdown]
# **Of the 5 positions, which position scores the most points?**
#
# We first group players by their positions.

# %%
pos = df.groupby(["Pos", "Player"]).sum()

# %%
pos[pos.PTS == pos.PTS.max()]
# Out:
#                    Rk  Age         Tm    G   GS     MP    FG   FGA    FG%  \
# Pos Player
# SG  CJ McCollum  1086   90  TOTPORNOP  124  124  103.6  26.2  56.5  1.389
#
#                   3P  ...    FT%  ORB   DRB   TRB   AST  STL  BLK  TOV   PF  \
# Pos Player            ...
# SG  CJ McCollum  8.7  ...  2.055  2.5  10.5  13.1  15.4  3.4  1.0  6.1  5.8
#
#                   PTS
# Pos Player
# SG  CJ McCollum  66.9
#
# [1 rows x 28 columns]

# %% [markdown]
# We will now show only the 5 traditional positions (those having combo positions will be removed from the analysis).

# %% [markdown]
# Now, let's take a look at the descriptive statistics.

# %% [markdown]
# ### **Histograms**

# %% [markdown]
# We'll also try to answer this question by showing some histogram plots. So, to make it a bit easier, let's create a subset dataframe.

# %%
PTS = df[["Pos", "PTS"]]
PTS
# Out:
#     Pos   PTS
# 0     C   9.1
# 1     C   6.9
# 2     C  19.1
# 3    PF   4.1
# 4     C  12.9
# ..   ..   ...
# 807  PF   6.3
# 808  PG  28.4
# 809   C   5.3
# 810   C   5.2
# 811   C  10.3
#
# [812 rows x 2 columns]

# %% [markdown]
# #### **pandas built-in visualization**

# %%
PTS.hist("PTS")
# Out:
# array([[<Axes: title={'center': 'PTS'}>]], dtype=object)

# %% [markdown]
# #### **Seaborn data visualization**

# %%
import seaborn as sns
import matplotlib.pyplot as plt

g = sns.FacetGrid(PTS, col="Pos")
g.map(plt.hist, "PTS");

# %% [markdown]
# ### **Box plots**

# %% [markdown]
# #### **Box plot of points scored (PTS) grouped by Position**

# %% [markdown]
# ##### **pandas built-in visualization**

# %% [markdown]
# ##### **Seaborn data visualization**

# %%
import seaborn as sns

sns.boxplot(x = 'Pos', y = 'PTS', data = PTS)

# %%
sns.boxplot(x = 'Pos', y = 'PTS', data = PTS) 
sns.stripplot(x = 'Pos', y = 'PTS', data = PTS,
              jitter=True, 
              marker='o',
              alpha=0.8, 
              color="black")

# %% [markdown]
# ### **Heat map**

# %% [markdown]
# #### Compute the correlation matrix

# %% [markdown]
# #### Make the heat map

# %% [markdown]
# #### Adjust figure size of heat map

# %%
import seaborn as sns
import matplotlib.pyplot as plt

fig, ax = plt.subplots(figsize=(7,5))
sns.heatmap(corr, square=True)

# %% [markdown]
# #### Mask diagonal half of heat map (Diagonal correlation matrix)

# %%
# https://seaborn.pydata.org/generated/seaborn.heatmap.html

import numpy as np
import seaborn as sns

mask = np.zeros_like(corr)
mask[np.triu_indices_from(mask)] = True
with sns.axes_style("white"):
    f, ax = plt.subplots(figsize=(7, 5))
    ax = sns.heatmap(corr, mask=mask, vmax=1, square=True)

# %% [markdown]
# ### **Scatter Plot**

# %%
df

# %% [markdown]
# #### Select columns if they have numerical data types

# %% [markdown]
# #### Select the first 5 columns (by index number)

# %% [markdown]
# #### Select 5 specific columns (by column names)

# %%
selections = ['Age', 'G', 'STL', 'BLK', 'AST', 'PTS']

# %% [markdown]
# #### Make scatter plot grid

# %% [markdown]
# ##### 5 columns

# %% [markdown]
# ##### All columns
